# %%
import wandb
import pandas as pd
import numpy as np
import json
import seaborn as sns

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
api = wandb.Api()

# %%
runs = api.runs(path="harvardml/opt-olmo")

# %%
optimizers = ['sgdw', 'adamw', 'novagradw_ours', 'adafactorw', 'lionw', 'signsgd',  'sophiag',] 
display_names = ['SGD', 'Adam',   'NovoGrad', 'Adafactor', 'Lion', 'Signum', 'Sophia G',]
colors = sns.color_palette('Set2', n_colors=len(optimizers))

color_map = dict(zip(optimizers, colors))
name_map = dict(zip(optimizers, display_names))

# %%
df = pd.DataFrame()

steps = [100, 300, 500, 900, 1700, 2900, 4900, 8500, 14600, 25000]
step = 25000
groups = ["optimizers-150-wd-noqk-1"]
plot_key = "learning_rate"
display_key = "Learning Rate"

for run in runs:
    if run.group in groups:
        history = run.history(samples=50000, 
                        keys=[
                            "eval/c4_val/CrossEntropyLoss", 
                            "train/CrossEntropyLoss", 
                            "optim/total_grad_norm",
                            ])
    
        run_dict = {}
        run_dict["id"] = run.id
        run_dict["group"] = run.group
        run_dict["optimizer"] = run.config["optimizer"]["name"]
        run_dict[plot_key] = run.config["optimizer"][plot_key]

        if run.group == "optimizers-1" and run_dict["optimizer"] == "sgdw":
            continue
        
        if "eval/c4_val/CrossEntropyLoss" in history:
            if step not in list(history["_step"]):
                run_dict["val_loss"] = 10.0
            else:
                run_dict["val_loss"] = list(history[history["_step"] == step]["eval/c4_val/CrossEntropyLoss"])[0]
                run_dict["step"] = step
        else:
            run_dict["val_loss"] = np.nan
            run_dict["step"] = np.nan
        if run_dict["optimizer"] == "novagradw" and run.config["optimizer"]["att_correction"]:
            run_dict["optimizer"] = "novagradw_ours"
        if (run_dict["optimizer"] == "adafactorw" and 
            "neuron_only" in run.config["optimizer"] and
            run.config["optimizer"]["neuron_only"]
        ):
            run_dict["optimizer"] = "adafactorw_oneside"
        run_df = pd.DataFrame(run_dict, index=[0])
        df = pd.concat([df, run_df])

# %%
df
# Out:
#          id                     group       optimizer  learning_rate  \
# 0  zj5pdb6l  optimizers-150-wd-noqk-1         signsgd       0.031600
# 0  z8chazbn  optimizers-150-wd-noqk-1      adafactorw       0.000316
# 0  yu4uptxf  optimizers-150-wd-noqk-1      adafactorw       1.000000
# 0  ww8ucklp  optimizers-150-wd-noqk-1         signsgd       0.010000
# 0  ut3tst8q  optimizers-150-wd-noqk-1           lionw       0.000032
# 0  tz2g4yii  optimizers-150-wd-noqk-1      adafactorw       0.003160
# 0  t543ne6f  optimizers-150-wd-noqk-1  novagradw_ours       0.000100
# 0  t172240k  optimizers-150-wd-noqk-1         signsgd       0.100000
# 0  ru889c2j  optimizers-150-wd-noqk-1           lionw       0.000100
# 0  r4k0v4lm  optimizers-150-wd-noqk-1  novagradw_ours       0.003160
# 0  qvnklrbc  optimizers-150-wd-noqk-1  novagradw_ours       0.100000
# 0  qmgkpvvc  optimizers-150-wd-noqk-1  novagradw_ours       0.316000
# 0  qlc4k1nf  optimizers-150-wd-noqk-1           adamw       1.000000
# 0  pqusszrl  optimizers-150-wd-noqk-1      adafactorw       0.100000
# 0  o0zfkynt  optimizers-150-wd-noqk-1           lionw       0.000010
# 0  my86hbf7  optimizers-150-wd-noqk-1      adafactorw       0.031600
# 0  mwww178t  optimizers-150-wd-noqk-1            sgdw       0.003160
# 0  lqtgpl4u  optimizers-150-wd-noqk-1            sgdw       0.001000
# 0  fn6ssuyy  optimizers-150-wd-noqk-1           lionw       0.003160
# 0  ffi2i0ww  optimizers-150-wd-noqk-1  novagradw_ours       0.001000
# 0  dhtz8ylk  optimizers-150-wd-noqk-1      adafactorw       0.010000
# 0  d14ongop  optimizers-150-wd-noqk-1      adafactorw       0.000100
# 0  afa5ossi  optimizers-150-wd-noqk-1         signsgd       0.001000
# 0  a0v6y9sn  optimizers-150-wd-noqk-1      adafactorw       0.316000
# 0  8vy10ba2  optimizers-150-wd-noqk-1           lionw       0.010000
# 0  831o6w3t  optimizers-150-wd-noqk-1         signsgd       0.003160
# 0  6bkf49gz  optimizers-150-wd-noqk-1  novagradw_ours       1.000000
# 0  5qiqfrxe  optimizers-150-wd-noqk-1      adafactorw       0.001000
# 0  2j6i5lrr  optimizers-150-wd-noqk-1  novagradw_ours       0.010000
# 0  0g268lj9  optimizers-150-wd-noqk-1  novagradw_ours       0.031600
# 0  zzgmzp55  optimizers-150-wd-noqk-1           adamw       0.000316
# 0  yvr3nrn4  optimizers-150-wd-noqk-1            sgdw       0.100000
# 0  yi2vbbbv  optimizers-150-wd-noqk-1           lionw       0.100000
# 0  xr6ux6hl  optimizers-150-wd-noqk-1         signsgd       0.000032
# 0  wmx93i92  optimizers-150-wd-noqk-1         signsgd       0.000010
# 0  vqvgxvcc  optimizers-150-wd-noqk-1           lionw       0.001000
# 0  uze9ktlv  optimizers-150-wd-noqk-1           adamw       0.003160
# 0  qn9udpkp  optimizers-150-wd-noqk-1            sgdw       3.160000
# 0  pp2b09ns  optimizers-150-wd-noqk-1           adamw       0.000100
# 0  owdmyx6l  optimizers-150-wd-noqk-1            sgdw       0.316000
# 0  nogeniwb  optimizers-150-wd-noqk-1            sgdw       0.010000
# 0  hw6tk7ed  optimizers-150-wd-noqk-1           adamw       0.010000
# 0  hfkazbw4  optimizers-150-wd-noqk-1           lionw       0.031600
# 0  eyuhd2pa  optimizers-150-wd-noqk-1         signsgd       0.000100
# 0  cgawixe1  optimizers-150-wd-noqk-1            sgdw       0.031600
# 0  8r1za07m  optimizers-150-wd-noqk-1           adamw       0.100000
# 0  8lofiaaq  optimizers-150-wd-noqk-1         signsgd       0.000316
# 0  7pq7x18y  optimizers-150-wd-noqk-1  novagradw_ours       0.000316
# 0  6r4n7ynf  optimizers-150-wd-noqk-1           adamw       0.031600
# 0  67o7y11q  optimizers-150-wd-noqk-1            sgdw       1.000000
# 0  621ot3i2  optimizers-150-wd-noqk-1           adamw       0.001000
# 0  5nyw6p8p  optimizers-150-wd-noqk-1            sgdw      10.000000
# 0  4eqrilkt  optimizers-150-wd-noqk-1           lionw       0.000316
# 0  3miesq61  optimizers-150-wd-noqk-1           adamw       0.316000
#
#     val_loss     step
# 0  10.000000      NaN
# 0   3.141621  25000.0
# 0        NaN      NaN
# 0  10.000000      NaN
# 0   3.240644  25000.0
# 0   3.080710  25000.0
# 0   3.370636  25000.0
# 0  10.000000      NaN
# 0   3.109689  25000.0
# 0   3.113886  25000.0
# 0  10.000000      NaN
# 0  10.000000      NaN
# 0        NaN      NaN
# 0  10.000000      NaN
# 0   3.506258  25000.0
# 0  10.000000      NaN
# 0   4.741189  25000.0
# 0   5.487525  25000.0
# 0  10.000000      NaN
# 0   3.095036  25000.0
# 0  10.000000      NaN
# 0   3.326158  25000.0
# 0   3.090623  25000.0
# 0  10.000000      NaN
# 0  10.000000      NaN
# 0  10.000000      NaN
# 0        NaN      NaN
# 0   3.073274  25000.0
# 0  15.385399  25000.0
# 0   7.622596  25000.0
# 0   3.153193  25000.0
# 0   3.350025  25000.0
# 0  10.000000      NaN
# 0   3.295158  25000.0
# 0   3.588992  25000.0
# 0   3.085926  25000.0
# 0   3.081872  25000.0
# 0  10.000000      NaN
# 0   3.336343  25000.0
# 0   3.193129  25000.0
# 0   3.956768  25000.0
# 0   7.167523  25000.0
# 0  10.000000      NaN
# 0   3.140944  25000.0
# 0   3.562336  25000.0
# 0   9.535127  25000.0
# 0   3.081797  25000.0
# 0   3.168769  25000.0
# 0   7.311240  25000.0
# 0   3.120555  25000.0
# 0   3.081550  25000.0
# 0  10.000000      NaN
# 0   3.064551  25000.0
# 0  10.000000      NaN

# %%
df["optimizer"].unique()
# Out:
# array(['signsgd', 'adafactorw', 'lionw', 'novagradw_ours', 'adamw',
#        'sgdw'], dtype=object)

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))  # Larger figure size


best_lrs = {}
for optimizer in optimizers:
    if optimizer in df["optimizer"].unique():
        optimizer_df = df[df["optimizer"] == optimizer]
        optimizer_df = optimizer_df.sort_values(by=plot_key)
        optimizer_df = optimizer_df.groupby(plot_key).min().reset_index()
        plt.plot(optimizer_df[plot_key], optimizer_df["val_loss"], label=name_map[optimizer], color=color_map[optimizer])
        
        best_lr = optimizer_df[plot_key][optimizer_df["val_loss"].idxmin()]
        best_lrs[optimizer] = best_lr

plt.xscale("log")
#plt.yscale("log")
#plt.ylim(3, 4)
plt.legend()
plt.xlabel(display_key)
plt.ylabel("Final Validation Loss")
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(5, 3), dpi=200)  # Larger figure size


adam_lr = best_lrs["adamw"]
multipliers = {k: adam_lr / v for k,v in best_lrs.items()}

for optimizer in optimizers:
    if optimizer in ["sophiag", "novagradw_ours"]:
        continue
    if optimizer in df["optimizer"].unique():
        optimizer_df = df[df["optimizer"] == optimizer]
        optimizer_df = optimizer_df.sort_values(by="learning_rate")
        # take minimal value for each learning rate
        optimizer_df = optimizer_df.groupby("learning_rate").min().reset_index()
        plt.plot(
            multipliers[optimizer] * optimizer_df["learning_rate"] / adam_lr, 
            optimizer_df["val_loss"], 
            label=name_map[optimizer],
            linewidth=2,
            color=color_map[optimizer],
            # linestyle='--' if optimizer in ['adamw', 'sgdw'] else '-'
        )

plt.xscale("log")
plt.xlim(3.2e-2, 1.5e2)
plt.ylim(3.05, 3.4)
plt.xlabel("Multiple of optimal LR")
plt.ylabel("Final Validation Loss")
plt.title("150m (no QK norm or z-loss + wd=1e-4 decoupled)")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), fancybox=True, shadow=False, ncol=len(optimizers))
plt.show()
