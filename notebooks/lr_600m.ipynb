# %%
import wandb
import pandas as pd
import numpy as np
import json
import seaborn as sns

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
api = wandb.Api()

# %%
runs = api.runs(path="harvardml/opt-olmo")

# %%
optimizers = ['sgdw', 'adamw', 'novagradw_ours', 'adafactorw', 'lionw', 'signsgd',  'sophiag',] 
display_names = ['SGD', 'Adam',   'NovoGrad', 'Adafactor', 'Lion', 'Sign SGD', 'Sophia G',]
colors = sns.color_palette('Set2', n_colors=len(optimizers))

color_map = dict(zip(optimizers, colors))
name_map = dict(zip(optimizers, display_names))

# %%
df = pd.DataFrame()

steps = [100, 300, 500, 900, 1700, 2900, 4900, 8500, 14600, 25000]
step = 100000
groups = ["optimizers-600-1"]
plot_key = "learning_rate"
display_key = "Learning Rate"

for run in runs:
    if run.group in groups:
        history = run.history(samples=100000, 
                        keys=[
                            "eval/c4_val/CrossEntropyLoss", 
                            "train/CrossEntropyLoss", 
                            "optim/total_grad_norm",
                            ])
    
        run_dict = {}
        run_dict["id"] = run.id
        run_dict["group"] = run.group
        run_dict["optimizer"] = run.config["optimizer"]["name"]
        run_dict[plot_key] = run.config["optimizer"][plot_key]

        if run.group == "optimizers-1" and run_dict["optimizer"] == "sgdw":
            continue
        
        if "eval/c4_val/CrossEntropyLoss" in history:
            if step not in list(history["_step"]):
                run_dict["val_loss"] = 10.0
            else:
                run_dict["val_loss"] = list(history[history["_step"] == step]["eval/c4_val/CrossEntropyLoss"])[0]
                run_dict["step"] = step
        else:
            run_dict["val_loss"] = np.nan
            run_dict["step"] = np.nan
        if run_dict["optimizer"] == "novagradw" and run.config["optimizer"]["att_correction"]:
            run_dict["optimizer"] = "novagradw_ours"
        if (run_dict["optimizer"] == "adafactorw" and 
            "neuron_only" in run.config["optimizer"] and
            run.config["optimizer"]["neuron_only"]
        ):
            run_dict["optimizer"] = "adafactorw_oneside"
        run_df = pd.DataFrame(run_dict, index=[0])
        df = pd.concat([df, run_df])

# %%
df
# Out:
#          id             group       optimizer  learning_rate   val_loss  \
# 0  tycrqlkr  optimizers-600-1           adamw       0.316000   2.884225
# 0  px2w8kfw  optimizers-600-1           adamw       1.000000  10.000000
# 0  ay54kifb  optimizers-600-1           adamw       0.100000   2.822815
# 0  1ukygxsy  optimizers-600-1           adamw       0.031600   2.771237
# 0  ixomzwss  optimizers-600-1            sgdw       0.031600   3.036421
# 0  cf1vrl1l  optimizers-600-1            sgdw       0.003160   3.753946
# 0  alhhdy97  optimizers-600-1            sgdw       0.001000   4.584732
# 0  58i3jqdf  optimizers-600-1            sgdw       0.010000   3.210201
# 0  xbmrca37  optimizers-600-1           adamw       0.010000   2.759208
# 0  8zr6caun  optimizers-600-1           adamw       0.003160   2.752204
# 0  u02adcb5  optimizers-600-1  novagradw_ours       0.000316   2.776675
# 0  ere3ycmt  optimizers-600-1  novagradw_ours       0.000100   2.850524
# 0  8sw8fb1p  optimizers-600-1  novagradw_ours       0.001000   2.768880
# 0  7xti7htb  optimizers-600-1      adafactorw       1.000000  10.000000
# 0  lspjjooo  optimizers-600-1      adafactorw       0.010000   2.763325
# 0  g739whrt  optimizers-600-1      adafactorw       0.316000  10.000000
# 0  8g4x69i9  optimizers-600-1      adafactorw       0.100000   2.798782
# 0  6caj9vhm  optimizers-600-1      adafactorw       0.031600   2.796798
# 0  s4c08z98  optimizers-600-1  novagradw_ours       0.010000   2.827509
# 0  mnhrbuln  optimizers-600-1           lionw       0.000010   2.911034
# 0  m5wljcwp  optimizers-600-1           lionw       0.000100   2.737247
# 0  icou7vk2  optimizers-600-1  novagradw_ours       0.316000  10.000000
# 0  g3rhk5z3  optimizers-600-1  novagradw_ours       0.031600   2.838377
# 0  fhh874s1  optimizers-600-1  novagradw_ours       1.000000        NaN
# 0  7w2e1gzq  optimizers-600-1           lionw       0.000316   2.726487
# 0  5k6nqc2j  optimizers-600-1  novagradw_ours       0.100000  10.000000
# 0  3t8wa7gs  optimizers-600-1           lionw       0.000032   2.786017
# 0  1cnzlsat  optimizers-600-1  novagradw_ours       0.003160   2.771408
# 0  znk52m3t  optimizers-600-1         signsgd       0.100000        NaN
# 0  z0v56pwd  optimizers-600-1           lionw       0.003160   2.795215
# 0  v0qcli7b  optimizers-600-1         signsgd       0.001000   2.756225
# 0  s83aht91  optimizers-600-1         signsgd       0.010000   2.828504
# 0  pnbxdjbg  optimizers-600-1         signsgd       0.000100   2.757559
# 0  p0vpvoe9  optimizers-600-1         signsgd       0.003160   2.800462
# 0  j0f0o6n2  optimizers-600-1         signsgd       0.031600   2.878319
# 0  dx596yya  optimizers-600-1      adafactorw       0.000100   2.820281
# 0  cufdku4d  optimizers-600-1           lionw       0.031600   2.847967
# 0  a3uny2zo  optimizers-600-1           lionw       0.001000   2.750318
# 0  4k0j2ft5  optimizers-600-1           lionw       0.010000   2.812737
# 0  3we564ik  optimizers-600-1         signsgd       0.000316   2.739498
# 0  khzhfap9  optimizers-600-1      adafactorw       0.001000   2.727058
# 0  fijh5qas  optimizers-600-1      adafactorw       0.003160   2.741157
# 0  5ox6mblf  optimizers-600-1      adafactorw       0.000316   2.748037
# 0  x33iim1a  optimizers-600-1            sgdw      10.000000        NaN
# 0  hj6khgbv  optimizers-600-1            sgdw       1.000000  10.000000
# 0  h3roto3j  optimizers-600-1            sgdw       3.160000  10.000000
# 0  3nepaihm  optimizers-600-1            sgdw       0.100000   2.920803
# 0  u2ttpmz4  optimizers-600-1           adamw       0.001000   2.739377
# 0  swn3ne3p  optimizers-600-1            sgdw       0.316000   2.830533
# 0  jkwouf7a  optimizers-600-1           adamw       0.000316   2.756966
# 0  j9i86ihh  optimizers-600-1         signsgd       0.000010   2.955163
# 0  b67zgwuh  optimizers-600-1           lionw       0.100000  10.000000
# 0  a0sm53rg  optimizers-600-1         signsgd       0.000032   2.819318
# 0  206gzoe1  optimizers-600-1           adamw       0.000100   2.830264
#
#        step
# 0  100000.0
# 0       NaN
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0       NaN
# 0  100000.0
# 0       NaN
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0       NaN
# 0  100000.0
# 0       NaN
# 0  100000.0
# 0       NaN
# 0  100000.0
# 0  100000.0
# 0       NaN
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0       NaN
# 0       NaN
# 0       NaN
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0  100000.0
# 0       NaN
# 0  100000.0
# 0  100000.0

# %%
df["optimizer"].unique()
# Out:
# array(['adamw', 'sgdw', 'novagradw_ours', 'adafactorw', 'lionw',
#        'signsgd'], dtype=object)

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))  # Larger figure size


best_lrs = {}
for optimizer in optimizers:
    if optimizer in df["optimizer"].unique():
        optimizer_df = df[df["optimizer"] == optimizer]
        optimizer_df = optimizer_df.sort_values(by=plot_key)
        optimizer_df = optimizer_df.groupby(plot_key).min().reset_index()
        plt.plot(optimizer_df[plot_key], optimizer_df["val_loss"], label=name_map[optimizer], color=color_map[optimizer])
        
        best_lr = optimizer_df[plot_key][optimizer_df["val_loss"].idxmin()]
        best_lrs[optimizer] = best_lr

plt.xscale("log")
#plt.yscale("log")
#plt.ylim(3, 4)
plt.legend()
plt.xlabel(display_key)
plt.ylabel("Final Validation Loss")
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(5, 3), dpi=200)  # Larger figure size

df_div = df.copy()

adam_lr = best_lrs["adamw"]
multipliers = {k: adam_lr / v for k,v in best_lrs.items()}

for optimizer in optimizers:
    if optimizer in ["sophiag", "novagradw_ours", "signsgd"]:
        continue
    if optimizer in df["optimizer"].unique():
        optimizer_df = df[df["optimizer"] == optimizer]
        optimizer_df = optimizer_df.sort_values(by="learning_rate")
        # take minimal value for each learning rate
        optimizer_df = optimizer_df.groupby("learning_rate").min().reset_index()
        plt.plot(
            multipliers[optimizer] * optimizer_df["learning_rate"] / adam_lr, 
            optimizer_df["val_loss"], 
            label=name_map[optimizer],
            linewidth=2,
            color=color_map[optimizer],
            # linestyle='--' if optimizer in ['adamw', 'sgdw'] else '-'
        )

plt.xscale("log")
plt.xlim(3.2e-2, 1.5e2)
plt.ylim(2.7, 3.05)
plt.xlabel("Multiple of optimal LR")
plt.ylabel("Final Validation Loss")
plt.title("600m (standard)")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), fancybox=True, shadow=False, ncol=len(optimizers))
plt.show()
