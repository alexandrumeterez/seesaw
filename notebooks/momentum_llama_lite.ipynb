# %%
import wandb
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
api = wandb.Api()

# %%
runs = api.runs(path="harvardml/opt-olmo")

# %%
optimizers = ['sgdw', 'adamw', 'novagradw_ours', 'adafactorw', 'lionw', 'signsgd',  'sophiag',] 
display_names = ['SGD', 'Adam',  'NovoGrad', 'Adafactor', 'Lion', 'Sign SGD', 'Sophia G',]
colors = sns.color_palette('Set2', n_colors=len(optimizers))

color_map = dict(zip(optimizers, colors))
name_map = dict(zip(optimizers, display_names))

# %%
df = pd.DataFrame()

steps = [100, 300, 500, 900, 1700, 2900, 4900, 8500, 14600, 25000]
step = 25000
groups = ["momentum-llama-lite-2", "momentum-llama-lite-3"]

for run in runs:
    if run.group in groups:
        history = run.history(samples=25000, 
                        keys=[
                            "eval/c4_val/CrossEntropyLoss", 
                            "train/CrossEntropyLoss", 
                            "optim/total_grad_norm",
                            ])
    
        run_dict = {}
        run_dict["id"] = run.id
        run_dict["name"] = run.name
        run_dict["group"] = run.group
        run_dict["optimizer"] = run.config["optimizer"]["name"]
        run_dict["learning_rate"] = run.config["optimizer"]["learning_rate"]
        run_dict["beta_0"] = run.config["optimizer"]["beta_0"]
        run_dict["beta_1"] = run.config["optimizer"]["beta_1"]
        run_dict["eps"] = run.config["optimizer"]["eps"]
        if "eval/c4_val/CrossEntropyLoss" in history:
            if step not in list(history["_step"]):
                run_dict["val_loss"] = 10.0
            else:
                run_dict["val_loss"] = list(history[history["_step"] == step]["eval/c4_val/CrossEntropyLoss"])[0]
                run_dict["step"] = step
        else:
            run_dict["val_loss"] = np.nan
            run_dict["step"] = np.nan
        if run_dict["optimizer"] == "novagradw" and run.config["optimizer"]["att_correction"]:
            run_dict["optimizer"] = "novagradw_ours"
        if (run_dict["optimizer"] == "adafactorw" and 
            "neuron_only" in run.config["optimizer"] and
            run.config["optimizer"]["neuron_only"]
        ):
            run_dict["optimizer"] = "adafactorw_oneside"
        run_df = pd.DataFrame(run_dict, index=[0])
        df = pd.concat([df, run_df])

# %%
df
# Out:
#          id              name                  group       optimizer  \
# 0  x604s45d   olmo_33559399_6  momentum-llama-lite-3            sgdw
# 0  qbdkzgoe   olmo_33559399_7  momentum-llama-lite-3            sgdw
# 0  l29ymtur   olmo_33559399_2  momentum-llama-lite-3            sgdw
# 0  dydhhuo8   olmo_33559399_5  momentum-llama-lite-3            sgdw
# 0  a7tsq26m   olmo_33559399_1  momentum-llama-lite-3            sgdw
# 0  8go7pdir   olmo_33559399_4  momentum-llama-lite-3            sgdw
# 0  1vztuecb   olmo_33559399_3  momentum-llama-lite-3            sgdw
# 0  c4xiuk1r  olmo_33446937_30  momentum-llama-lite-2      adafactorw
# 0  cweauly2  olmo_33407516_42  momentum-llama-lite-2  novagradw_ours
# 0  7wf2snvm  olmo_33407516_41  momentum-llama-lite-2  novagradw_ours
# 0  e1p3ei8w  olmo_33407516_40  momentum-llama-lite-2  novagradw_ours
# 0  q53tdj9l  olmo_33407516_39  momentum-llama-lite-2  novagradw_ours
# 0  wbzcmckk  olmo_33407516_38  momentum-llama-lite-2  novagradw_ours
# 0  n81dh18j  olmo_33407516_37  momentum-llama-lite-2  novagradw_ours
# 0  naehzvl6  olmo_33407516_17  momentum-llama-lite-2         signsgd
# 0  gwqojmdk  olmo_33407516_36  momentum-llama-lite-2  novagradw_ours
# 0  e5uhun8t  olmo_33407516_20  momentum-llama-lite-2         signsgd
# 0  0n3fbthv  olmo_33407516_34  momentum-llama-lite-2      adafactorw
# 0  wtdiv94c  olmo_33407516_23  momentum-llama-lite-2           lionw
# 0  dmhfbi8f  olmo_33407516_12  momentum-llama-lite-2            sgdw
# 0  9oir2eft  olmo_33407516_28  momentum-llama-lite-2           lionw
# 0  1wxsy1o4  olmo_33407516_13  momentum-llama-lite-2            sgdw
# 0  plddgugk  olmo_33407516_14  momentum-llama-lite-2            sgdw
# 0  jrd7i319  olmo_33407516_26  momentum-llama-lite-2           lionw
# 0  a3ndzg1b  olmo_33407516_10  momentum-llama-lite-2            sgdw
# 0  33oslu5n  olmo_33407516_33  momentum-llama-lite-2      adafactorw
# 0  k3eovhcq  olmo_33407516_24  momentum-llama-lite-2           lionw
# 0  yevxqp2m  olmo_33407516_15  momentum-llama-lite-2         signsgd
# 0  swdippjc  olmo_33407516_32  momentum-llama-lite-2      adafactorw
# 0  n3rmefui  olmo_33407516_18  momentum-llama-lite-2         signsgd
# 0  k6tavp5z  olmo_33407516_19  momentum-llama-lite-2         signsgd
# 0  ea59dsad  olmo_33407516_25  momentum-llama-lite-2           lionw
# 0  e96nl70u  olmo_33407516_30  momentum-llama-lite-2      adafactorw
# 0  3w2ro1rk   olmo_33407516_8  momentum-llama-lite-2            sgdw
# 0  31sagp4f  olmo_33407516_16  momentum-llama-lite-2         signsgd
# 0  feqmk9e8  olmo_33407516_35  momentum-llama-lite-2      adafactorw
# 0  dzltzbdw  olmo_33407516_11  momentum-llama-lite-2            sgdw
# 0  o3ivah7f  olmo_33407516_29  momentum-llama-lite-2      adafactorw
# 0  65r7to6p   olmo_33407516_7  momentum-llama-lite-2           adamw
# 0  0hs3u05g   olmo_33407516_9  momentum-llama-lite-2            sgdw
# 0  wbsb7piy  olmo_33407516_31  momentum-llama-lite-2      adafactorw
# 0  t28rjohu   olmo_33407516_5  momentum-llama-lite-2           adamw
# 0  2sjovamk   olmo_33407516_6  momentum-llama-lite-2           adamw
# 0  jy0zug2n  olmo_33407516_22  momentum-llama-lite-2           lionw
# 0  fqoi59lh   olmo_33407516_4  momentum-llama-lite-2           adamw
# 0  wb68t0nz  olmo_33407516_21  momentum-llama-lite-2         signsgd
# 0  f9f7bjg6   olmo_33407516_1  momentum-llama-lite-2           adamw
# 0  n050q4sq   olmo_33407516_3  momentum-llama-lite-2           adamw
# 0  k6v8z0sp  olmo_33407516_27  momentum-llama-lite-2           lionw
# 0  h4d3wsdq   olmo_33407516_2  momentum-llama-lite-2           adamw
#
#    learning_rate  beta_0  beta_1           eps   val_loss     step
# 0       1.000000    0.98    0.95  1.000000e-15   3.143589  25000.0
# 0       0.001000    0.90    0.95  1.000000e-15   3.081609  25000.0
# 0       0.000316    0.99    0.95  1.000000e-15   3.121310  25000.0
# 0       0.001000    0.00    0.95  1.000000e-15   3.123141  25000.0
# 0       0.001000    0.80    0.95  1.000000e-15   3.083501  25000.0
# 0       0.000316    0.98    0.95  1.000000e-15   3.177054  25000.0
# 0       0.001000    0.50    0.95  1.000000e-15   3.097597  25000.0

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(5, 3), dpi=200)  # Larger figure size

group_df = df

for optimizer in optimizers:
    if optimizer in ["sophiag"]:
        continue
    if optimizer in group_df["optimizer"].unique():
        optimizer_df = group_df[group_df["optimizer"] == optimizer]
        optimizer_df = optimizer_df.sort_values(by="beta_0")
        optimizer_df = optimizer_df.groupby("beta_0").min().reset_index()
        label = name_map.get(optimizer)
        if optimizer in ["lionw"]:
            label = "Lion (beta 1)"
        plt.plot(1 - optimizer_df["beta_0"], 
                optimizer_df["val_loss"], 
                label=label,
                linewidth=2,
                color=color_map[optimizer],
                linestyle='--' if optimizer in ['adamw', 'sgdw'] else '-'
        )
        # if optimizer in ["lionw"]:
        #     optimizer_df = df[(df["group"] == "beta-all-1") & (df["optimizer"] == "lionw")]
        #     optimizer_df = optimizer_df.sort_values(by="beta_1")
        #     optimizer_df = optimizer_df.groupby("beta_1").min().reset_index()
        #     label = "Lion (beta 2)"
        #     plt.plot(1 - optimizer_df["beta_1"], 
        #             optimizer_df["val_loss"], 
        #             label=label,
        #             linewidth=2,
        #             color=color_map["lionw"],
        #             linestyle=':',
        #     )


plt.xscale("log")
plt.ylim(3.05, 3.4)
plt.xlim(0.01, 1)

plt.xlabel("Momentum")
xs = [0.0, 0.5, 0.8, 0.9, 0.95, 0.98, 0.99][::-1]

xsa = 1 - np.array(xs)
plt.xticks(xsa, xs)
plt.ylabel("Final Validation Loss")
plt.title("No QK norm or z-loss")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), fancybox=True, shadow=False, ncol=len(optimizers) /2)
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(5, 3), dpi=200)  # Larger figure size

group_df = df

for optimizer in optimizers:
    if optimizer in ["sophiag", "novagradw_ours", "signsgd"]:
        continue
    if optimizer in group_df["optimizer"].unique():
        optimizer_df = group_df[group_df["optimizer"] == optimizer]
        optimizer_df = optimizer_df.sort_values(by="beta_0")
        optimizer_df = optimizer_df.groupby("beta_0").min().reset_index()
        label = name_map.get(optimizer)
        # if optimizer in ["lionw"]:
        #     label = "Lion (beta 1)"
        plt.plot(1 - optimizer_df["beta_0"], 
                optimizer_df["val_loss"], 
                label=label,
                linewidth=2,
                color=color_map[optimizer],
                #linestyle='--' if optimizer in ['adamw', 'sgdw'] else '-'
        )
        # if optimizer in ["lionw"]:
        #     optimizer_df = df[(df["group"] == "beta-all-1") & (df["optimizer"] == "lionw")]
        #     optimizer_df = optimizer_df.sort_values(by="beta_1")
        #     optimizer_df = optimizer_df.groupby("beta_1").min().reset_index()
        #     label = "Lion (beta 2)"
        #     plt.plot(1 - optimizer_df["beta_1"], 
        #             optimizer_df["val_loss"], 
        #             label=label,
        #             linewidth=2,
        #             color=color_map["lionw"],
        #             linestyle=':',
        #     )


plt.xscale("log")
plt.ylim(3.05, 3.4)
plt.xlim(0.01, 1)

plt.xlabel("beta_1")
xs = [0.0, 0.5, 0.8, 0.9, 0.95, 0.98, 0.99][::-1]

xsa = 1 - np.array(xs)
plt.xticks(xsa, xs)
plt.ylabel("Final Validation Loss")
plt.title("150m (no QK norm or z-loss)")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), fancybox=True, shadow=False, ncol=len(optimizers))
plt.show()
