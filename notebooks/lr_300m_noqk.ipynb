# %%
import wandb
import pandas as pd
import numpy as np
import json
import seaborn as sns

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
api = wandb.Api()

# %%
runs = api.runs(path="harvardml/opt-olmo")

# %%
optimizers = ['sgdw', 'adamw', 'novagradw_ours', 'adafactorw', 'lionw', 'signsgd',  'sophiag',] 
display_names = ['SGD', 'Adam',   'NovoGrad', 'Adafactor', 'Lion', 'Sign SGD', 'Sophia G',]
colors = sns.color_palette('Set2', n_colors=len(optimizers))

color_map = dict(zip(optimizers, colors))
name_map = dict(zip(optimizers, display_names))

# %%
df = pd.DataFrame()

steps = [100, 300, 500, 900, 1700, 2900, 4900, 8500, 14600, 25000]
step = 50000
groups = ["optimizers-llama-lite-300-2"]
plot_key = "learning_rate"
display_key = "Learning Rate"

for run in runs:
    if run.group in groups:
        history = run.history(samples=50000, 
                        keys=[
                            "eval/c4_val/CrossEntropyLoss", 
                            "train/CrossEntropyLoss", 
                            "optim/total_grad_norm",
                            ])
    
        run_dict = {}
        run_dict["id"] = run.id
        run_dict["group"] = run.group
        run_dict["optimizer"] = run.config["optimizer"]["name"]
        run_dict[plot_key] = run.config["optimizer"][plot_key]

        if run.group == "optimizers-1" and run_dict["optimizer"] == "sgdw":
            continue
        
        if "eval/c4_val/CrossEntropyLoss" in history:
            if step not in list(history["_step"]):
                run_dict["val_loss"] = 10.0
            else:
                run_dict["val_loss"] = list(history[history["_step"] == step]["eval/c4_val/CrossEntropyLoss"])[0]
                run_dict["step"] = step
        else:
            run_dict["val_loss"] = np.nan
            run_dict["step"] = np.nan
        if run_dict["optimizer"] == "novagradw" and run.config["optimizer"]["att_correction"]:
            run_dict["optimizer"] = "novagradw_ours"
        if (run_dict["optimizer"] == "adafactorw" and 
            "neuron_only" in run.config["optimizer"] and
            run.config["optimizer"]["neuron_only"]
        ):
            run_dict["optimizer"] = "adafactorw_oneside"
        run_df = pd.DataFrame(run_dict, index=[0])
        df = pd.concat([df, run_df])

# %%
df
# Out:
#          id                        group       optimizer  learning_rate  \
# 0  u9qzap5w  optimizers-llama-lite-300-2  novagradw_ours       1.000000
# 0  igsg4kvu  optimizers-llama-lite-300-2  novagradw_ours       0.316000
# 0  wtey9riz  optimizers-llama-lite-300-2  novagradw_ours       0.100000
# 0  4h7qhqf3  optimizers-llama-lite-300-2  novagradw_ours       0.010000
# 0  2s3h3bo4  optimizers-llama-lite-300-2  novagradw_ours       0.031600
# 0  vmn9xwhf  optimizers-llama-lite-300-2  novagradw_ours       0.003160
# 0  g0q8hgdk  optimizers-llama-lite-300-2  novagradw_ours       0.000316
# 0  b7scapwn  optimizers-llama-lite-300-2  novagradw_ours       0.000100
# 0  0dsecto3  optimizers-llama-lite-300-2      adafactorw       1.000000
# 0  p8odyhoq  optimizers-llama-lite-300-2      adafactorw       0.100000
# 0  o0kehjkm  optimizers-llama-lite-300-2      adafactorw       0.316000
# 0  uu43s6sy  optimizers-llama-lite-300-2      adafactorw       0.031600
# 0  hy7bqhm1  optimizers-llama-lite-300-2      adafactorw       0.010000
# 0  qqitqc7d  optimizers-llama-lite-300-2      adafactorw       0.003160
# 0  74zz90lu  optimizers-llama-lite-300-2      adafactorw       0.001000
# 0  n7woep0j  optimizers-llama-lite-300-2      adafactorw       0.000316
# 0  p8k11p3g  optimizers-llama-lite-300-2      adafactorw       0.000100
# 0  h7esh0jv  optimizers-llama-lite-300-2         signsgd       0.100000
# 0  zns5xfsd  optimizers-llama-lite-300-2         signsgd       0.031600
# 0  et6h3zbp  optimizers-llama-lite-300-2         signsgd       0.003160
# 0  a9lluqtz  optimizers-llama-lite-300-2         signsgd       0.010000
# 0  ffa4xs7y  optimizers-llama-lite-300-2         signsgd       0.000316
# 0  alkybje8  optimizers-llama-lite-300-2         signsgd       0.001000
# 0  afbcuup2  optimizers-llama-lite-300-2         signsgd       0.000100
# 0  sv5ssqja  optimizers-llama-lite-300-2         signsgd       0.000032
# 0  36qrr9si  optimizers-llama-lite-300-2         signsgd       0.000010
# 0  46ur8yup  optimizers-llama-lite-300-2           lionw       0.100000
# 0  0od1oiua  optimizers-llama-lite-300-2           lionw       0.031600
# 0  4aqioi1x  optimizers-llama-lite-300-2           lionw       0.010000
# 0  38sl04n7  optimizers-llama-lite-300-2           lionw       0.003160
# 0  tqo4z3ya  optimizers-llama-lite-300-2           lionw       0.001000
# 0  lotjttvb  optimizers-llama-lite-300-2           lionw       0.000316
# 0  7dl4275e  optimizers-llama-lite-300-2           lionw       0.000100
# 0  f5vld9ro  optimizers-llama-lite-300-2           lionw       0.000032
# 0  wdgxel6c  optimizers-llama-lite-300-2           lionw       0.000010
# 0  m2uz9qy0  optimizers-llama-lite-300-2            sgdw      10.000000
# 0  ljpupwwm  optimizers-llama-lite-300-2            sgdw       3.160000
# 0  jq0211ko  optimizers-llama-lite-300-2            sgdw       1.000000
# 0  9u8y2oac  optimizers-llama-lite-300-2            sgdw       0.100000
# 0  9lxelkxh  optimizers-llama-lite-300-2            sgdw       0.316000
# 0  tvbh21y5  optimizers-llama-lite-300-2            sgdw       0.010000
# 0  fjmt17n5  optimizers-llama-lite-300-2            sgdw       0.031600
# 0  qdrm5z01  optimizers-llama-lite-300-2            sgdw       0.003160
# 0  e6hf4dan  optimizers-llama-lite-300-2            sgdw       0.001000
# 0  7jzlwwdt  optimizers-llama-lite-300-2           adamw       0.100000
# 0  5jhzaun6  optimizers-llama-lite-300-2           adamw       0.031600
# 0  sq1swaaj  optimizers-llama-lite-300-2           adamw       1.000000
# 0  9x4l0bud  optimizers-llama-lite-300-2           adamw       0.316000
# 0  70v20qac  optimizers-llama-lite-300-2           adamw       0.010000
# 0  6xdu8xnw  optimizers-llama-lite-300-2           adamw       0.001000
# 0  q8b2wch1  optimizers-llama-lite-300-2           adamw       0.000316
# 0  q7wxvtww  optimizers-llama-lite-300-2           adamw       0.003160
# 0  c25hkbu5  optimizers-llama-lite-300-2           adamw       0.000100
#
#     val_loss     step
# 0        NaN      NaN
# 0  62.613815  50000.0
# 0  10.000000      NaN
# 0  23.293488  50000.0
# 0  34.627728  50000.0
# 0   2.933158  50000.0
# 0   2.949210  50000.0
# 0   3.084686  50000.0
# 0        NaN      NaN
# 0  10.000000      NaN
# 0  10.000000      NaN
# 0  10.000000      NaN
# 0  10.000000      NaN
# 0   2.910948  50000.0
# 0   2.892584  50000.0
# 0   2.930058  50000.0
# 0   3.043738  50000.0
# 0        NaN      NaN
# 0  10.000000      NaN
# 0  10.000000      NaN
# 0  10.000000      NaN
# 0   2.898438  50000.0
# 0   2.911440  50000.0
# 0   2.933246  50000.0
# 0   3.037003  50000.0
# 0   3.234978  50000.0
# 0        NaN      NaN
# 0  10.000000      NaN
# 0  10.000000      NaN
# 0  10.000000      NaN
# 0   2.914365  50000.0
# 0   2.880117  50000.0
# 0   2.906930  50000.0
# 0   2.994471  50000.0
# 0   3.172827  50000.0
# 0        NaN      NaN
# 0  10.000000      NaN
# 0  10.000000      NaN
# 0   3.140814  50000.0
# 0   3.023995  50000.0
# 0   3.595980  50000.0
# 0   3.296969  50000.0
# 0   4.306637  50000.0
# 0   5.163802  50000.0
# 0  10.000000      NaN
# 0   7.291464  50000.0
# 0        NaN      NaN
# 0  29.007111  50000.0
# 0   2.987277  50000.0
# 0   2.902427  50000.0
# 0   2.938999  50000.0
# 0   2.910626  50000.0
# 0   3.058123  50000.0

# %%
df["optimizer"].unique()
# Out:
# array(['novagradw_ours', 'adafactorw', 'signsgd', 'lionw', 'sgdw',
#        'adamw'], dtype=object)

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))  # Larger figure size


best_lrs = {}
for optimizer in optimizers:
    if optimizer in df["optimizer"].unique():
        optimizer_df = df[df["optimizer"] == optimizer]
        optimizer_df = optimizer_df.sort_values(by=plot_key)
        optimizer_df = optimizer_df.groupby(plot_key).min().reset_index()
        plt.plot(optimizer_df[plot_key], optimizer_df["val_loss"], label=name_map[optimizer], color=color_map[optimizer])
        
        best_lr = optimizer_df[plot_key][optimizer_df["val_loss"].idxmin()]
        best_lrs[optimizer] = best_lr

plt.xscale("log")
#plt.yscale("log")
#plt.ylim(3, 4)
plt.legend()
plt.xlabel(display_key)
plt.ylabel("Final Validation Loss")
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(5, 3), dpi=200)  # Larger figure size

df_div = df.copy()

adam_lr = best_lrs["adamw"]
multipliers = {k: adam_lr / v for k,v in best_lrs.items()}

for optimizer in optimizers:
    if optimizer in ["sophiag", "novagradw_ours", "signsgd"]:
        continue
    if optimizer in df["optimizer"].unique():
        optimizer_df = df[df["optimizer"] == optimizer]
        optimizer_df = optimizer_df.sort_values(by="learning_rate")
        # take minimal value for each learning rate
        optimizer_df = optimizer_df.groupby("learning_rate").min().reset_index()
        plt.plot(
            multipliers[optimizer] * optimizer_df["learning_rate"] / adam_lr, 
            optimizer_df["val_loss"], 
            label=name_map[optimizer],
            linewidth=2,
            color=color_map[optimizer],
            #linestyle='--' if optimizer in ['adamw', 'sgdw'] else '-'
        )

plt.xscale("log")
plt.xlim(3.2e-2, 1.5e2)
plt.ylim(2.85, 3.2)
plt.xlabel("Multiple of optimal LR")
plt.ylabel("Final Validation Loss")
plt.title("300m (no QK norm or z-loss)")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), fancybox=True, shadow=False, ncol=len(optimizers))
plt.show()
